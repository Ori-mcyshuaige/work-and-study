# %% [markdown]
# # Try AIM
#
# Copyright: GeneGenieDx Corp 2022
#
# Author: Wenhao Gu
#
# Date of creation: 04/06/2022
#
# Date of revision: 05/24/2022
#
# Description: Examples for using the AIM library.

# %%
import os
os.environ["PYTHONWARNINGS"] = "ignore"

from sklearn.datasets import make_moons, make_circles

from select_feature_types import *

# %% [markdown]
# # 1. Example of make_moons.

# %%
# Generate dataset and preprocess.
X, y = make_moons(n_samples=500, shuffle=False, noise=.3, random_state=123)

preprocessed_X = preprocess(X)
feature_matrix = pd.DataFrame(
    {"f0": preprocessed_X[:, 0], "f1": preprocessed_X[:, 1], "label": y}
)

# %%
plt.plot(X[y==0,0],X[y==0,1],'ro')
plt.plot(X[y==1,0],X[y==1,1],'bo')

# %%
# Split the dataset.
train_X, train_y, test_X, test_y = prepare_train_test_data(
    feature_matrix, ["f0", "f1"], test_ratio=0.2, random_state=123
)

# Train SVM with auto parameter optimization.
classifier, accuracy, feature_importance = train(
    train_X, train_y, test_X, test_y, model_type=ModelType.SVM, metrics=Metrics.Accuracy, display_cv_results=True
)
# Out:
# Best parameters selected: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Support vectors: [[0.37159573 0.55002824]
#  [0.70789706 0.52967367]
#  [0.62350803 0.24754355]
#  [0.32602346 0.57115428]
#  [0.71008217 0.26420484]
#  [0.76570433 0.29896771]
#  [0.58769542 0.52544087]
#  [0.37122839 0.57466681]
#  [0.27817422 0.29150698]
#  [0.39045203 0.58361245]
#  [0.44988704 0.60527685]
#  [0.71691787 0.44067502]
#  [0.66586367 0.45821238]
#  [0.66427816 0.45781796]
#  [0.28600495 0.46585787]
#  [0.51586769 0.54275788]
#  [0.6058208  0.51727817]
#  [0.72698891 0.39651124]
#  [0.62551754 0.51917961]
#  [0.56570612 0.47458523]
#  [0.62254231 0.48535192]
#  [0.4927832  0.53208445]
#  [0.41467067 0.5292419 ]
#  [0.33732292 0.56352079]
#  [0.67088157 0.42777217]
#  [0.75353926 0.65402824]
#  [0.2382791  0.26876538]
#  [0.71815649 0.34785639]
#  [0.76351378 0.35608352]
#  [0.64873886 0.42839267]
#  [0.63248868 0.12881903]
#  [0.62183567 0.36017466]
#  [0.57703025 0.47014141]
#  [0.34426604 0.50536531]
#  [0.64924825 0.49064603]
#  [0.80730744 0.47318808]
#  [0.38381621 0.53743526]
#  [0.59513511 0.52688986]
#  [0.57826205 0.48373292]
#  [0.66511033 0.50925289]
#  [0.74027911 0.53234857]
#  [0.61733263 0.44973656]
#  [0.71299883 0.56286794]
#  [0.66525206 0.44658162]
#  [0.26429593 0.43870382]
#  [0.39833184 0.57391583]
#  [0.46273851 0.57268872]
#  [0.59515049 0.2486192 ]
#  [0.31096765 0.4437481 ]
#  [0.43615725 0.60134847]
#  [0.42170862 0.60908021]
#  [0.57451708 0.54028809]
#  [0.7495345  0.3297674 ]
#  [0.74081651 0.48381033]
#  [0.50325761 0.56649325]
#  [0.56643706 0.34269909]
#  [0.22498519 0.21998003]
#  [0.5616541  0.3294323 ]
#  [0.336898   0.52501041]
#  [0.66930138 0.2306524 ]
#  [0.59038747 0.45152658]
#  [0.43800464 0.49115416]
#  [0.4854984  0.48144459]
#  [0.45763199 0.58095416]
#  [0.63747149 0.3271516 ]
#  [0.39673233 0.60737722]
#  [0.55842001 0.46206584]
#  [0.47651633 0.44794754]
#  [0.78911957 0.56867747]
#  [0.57830981 0.55892824]
#  [0.76514251 0.5533465 ]
#  [0.46741852 0.47246261]
#  [0.7537531  0.47028245]
#  [0.45379    0.48064994]
#  [0.68071633 0.48490419]
#  [0.5607391  0.45097414]
#  [0.38291613 0.57741713]
#  [0.47413619 0.58392182]
#  [0.60076669 0.34662097]
#  [0.71197794 0.38412111]
#  [0.71837864 0.39469616]
#  [0.61573095 0.33161831]
#  [0.44638043 0.44914651]
#  [0.47413935 0.50588228]
#  [0.44633443 0.52389866]
#  [0.44022057 0.1370417 ]
#  [0.3684716  0.4294216 ]
#  [0.62300207 0.4053923 ]
#  [0.75479346 0.37960201]
#  [0.67898756 0.39192584]
#  [0.82853542 0.60509744]
#  [0.56137388 0.6579587 ]
#  [0.68945566 0.00475985]
#  [0.45414364 0.45407563]
#  [0.69962604 0.29842845]
#  [0.64711582 0.28904855]
#  [0.47225106 0.44869512]
#  [0.72551216 0.32737146]
#  [0.77386617 0.45567698]
#  [0.45532173 0.61729791]
#  [0.63451478 0.09158283]
#  [0.50188009 0.64135066]
#  [0.72223572 0.46806557]
#  [0.49219628 0.54488164]
#  [0.52130361 0.44824292]
#  [0.79771917 0.51319737]
#  [0.64703118 0.43124027]
#  [0.70960242 0.404908  ]
#  [0.48540251 0.47849878]
#  [0.66243333 0.49778529]
#  [0.37507842 0.41332423]
#  [0.33289555 0.46388832]
#  [0.59805546 0.33443621]
#  [0.83209941 0.61683487]
#  [0.5022887  0.4460184 ]
#  [0.59560333 0.40793866]
#  [0.404446   0.54683474]]
# Cross-validated score of different parameter settings:     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.006040      0.000137         0.001381        0.000029       1
# 1        0.006312      0.000443         0.001244        0.000043      10
# 2        0.009449      0.000654         0.001297        0.000196     100
# 3        0.021272      0.001197         0.001245        0.000049    1000
# 4        0.010145      0.000963         0.003074        0.000267       1
# ..            ...           ...              ...             ...     ...
# 71       0.010623      0.000660         0.002174        0.000070    1000
# 72       0.011611      0.000876         0.002691        0.000062    1000
# 73       0.009071      0.000097         0.002610        0.000024    1000
# 74       0.010321      0.000160         0.002511        0.000062    1000
# 75       0.011573      0.000180         0.002743        0.000073    1000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale       linear
# 2        scale       linear
# 3        scale       linear
# 4         auto          rbf
# ..         ...          ...
# 71        0.01      sigmoid
# 72        0.01         poly
# 73       0.001          rbf
# 74       0.001      sigmoid
# 75       0.001         poly
#
#                                                params  split0_test_score  \
# 0      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}             0.8625
# 1     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}             0.8750
# 2    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}             0.8750
# 3   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}             0.8750
# 4          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}             0.8625
# ..                                                ...                ...
# 71    {'C': 1000, 'gamma': 0.01, 'kernel': 'sigmoid'}             0.8750
# 72       {'C': 1000, 'gamma': 0.01, 'kernel': 'poly'}             0.8250
# 73       {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}             0.8625
# 74   {'C': 1000, 'gamma': 0.001, 'kernel': 'sigmoid'}             0.8625
# 75      {'C': 1000, 'gamma': 0.001, 'kernel': 'poly'}             0.8250
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0             0.84375            0.80625            0.85000
# 1             0.83750            0.80625            0.85000
# 2             0.83750            0.81250            0.84375
# 3             0.83750            0.81250            0.85000
# 4             0.84375            0.80625            0.85000
# ..                ...                ...                ...
# 71            0.83750            0.80625            0.85000
# 72            0.50000            0.50000            0.50000
# 73            0.84375            0.80625            0.85000
# 74            0.84375            0.80625            0.85000
# 75            0.50000            0.50000            0.50000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.86250          0.84500        0.020691               37
# 1             0.87500          0.84875        0.025739               21
# 2             0.86875          0.84750        0.022569               28
# 3             0.86875          0.84875        0.022500               21
# 4             0.86875          0.84625        0.021866               32
# ..                ...              ...             ...              ...
# 71            0.87500          0.84875        0.025739               21
# 72            0.50000          0.56500        0.130000               68
# 73            0.87500          0.84750        0.023251               27
# 74            0.86250          0.84500        0.020691               37
# 75            0.50000          0.56500        0.130000               68
#
# [76 rows x 16 columns]

# %%
# Display model's performance.
print('Accuracy on the test set:', accuracy)
print("Feature's importance:", feature_importance)

# Plot ROC curve.
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
plt.ylim(0, 1)
plot_performance(classifier, test_X.values, test_y, pos_label=0, ax=axs[0])
plot_performance(classifier, test_X.values, test_y, pos_label=1, ax=axs[0])

# Plot P-R curve
plot_performance(classifier, test_X.values, test_y, pos_label=0, ax=axs[1], roc=False)
plot_performance(classifier, test_X.values, test_y, pos_label=1, ax=axs[1], roc=False)
# Out:
# Accuracy on the test set: 0.91
# Feature's importance: [('f1', 0.26800000000000007), ('f0', 0.22600000000000003)]

# %%
# Visualize the prediction.
predict_y = classifier.predict(test_X)
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
axs[0].scatter(test_X.iloc[:, 0], test_X.iloc[:, 1], c=test_y, s=15, cmap="viridis")
axs[0].set_title("Visualization of the test set with true label.", y=-0.1, fontsize=15)

axs[1].scatter(
    test_X.iloc[:, 0], test_X.iloc[:, 1], marker="o", s=15, c=predict_y, cmap="viridis",
)
axs[1].set_title(
    "Visualization of test set with model's prediction.", y=-0.1, fontsize=15
)
# Out:
# Text(0.5, -0.1, "Visualization of test set with model's prediction.")

# %%
# Select the best model
models_performance = []
for model_type in ModelType:
    print("Training %s :" % model_type.value)
    classifier, accuracy, feature_importance = train(
        train_X,
        train_y,
        test_X,
        test_y,
        model_type=model_type,
        metrics=Metrics.Accuracy,
        n_jobs=20,
    )
    models_performance.append((model_type.value, accuracy))

models_performance.sort(key=lambda t: t[1], reverse=True)
print("Best model type:", models_performance[0][0])
print("Performance of the best model type:", models_performance[0][1])
# Out:
# Training SVM :
# Best parameters selected: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Support vectors: [[0.73799631 0.50613408]
#  [0.6259615  0.87053217]
#  [0.73401527 0.70991949]
#  [0.54396679 0.52123095]
#  [0.47760932 0.51915942]
#  [0.79027533 0.47395767]
#  [0.73571459 0.52007747]
#  [0.30052779 0.58096265]
#  [0.66087868 0.45693567]
#  [0.68687062 0.42898794]
#  [0.58248676 0.37844284]
#  [0.66211234 0.42256303]
#  [0.43636197 0.69044156]
#  [0.41450707 0.6765027 ]
#  [0.23902438 0.4120493 ]
#  [0.62402277 0.37527035]
#  [0.65523604 0.32906588]
#  [0.41106868 0.65813768]
#  [0.50256757 0.47984792]
#  [0.35838077 0.65670829]
#  [0.53384613 0.48089069]
#  [0.44983204 0.48906508]
#  [0.65203261 0.33920539]
#  [0.39211879 0.57946309]
#  [0.52410398 0.58739286]
#  [0.55727341 1.        ]
#  [0.67452026 0.3778425 ]
#  [0.36435739 0.6411484 ]
#  [0.2191829  0.40191653]
#  [0.49578194 0.59018253]
#  [0.36580624 0.57146363]
#  [0.72409603 0.41312646]
#  [0.61285604 0.4198004 ]
#  [0.49970357 0.5014152 ]
#  [0.59863138 0.42113363]
#  [0.73250787 0.56182985]
#  [0.31735932 0.60060673]
#  [0.26776033 0.54634316]
#  [0.32758699 0.57122733]
#  [0.66418295 0.37262366]
#  [0.32953977 0.64375802]
#  [0.73364338 0.42078684]
#  [0.26578975 0.46028233]
#  [0.7678314  0.42954469]
#  [0.43593515 0.55853457]
#  [0.3358719  0.49121591]
#  [0.53379764 0.4199515 ]
#  [0.80998702 0.56232827]
#  [0.63641603 0.        ]
#  [0.62439773 0.39284973]
#  [0.74377686 0.39850215]
#  [0.47339321 0.48655561]
#  [0.4157686  0.59919407]
#  [0.39908769 0.53084779]
#  [0.55461578 0.5728682 ]
#  [0.66930165 0.35374718]
#  [0.33384855 0.63184102]
#  [0.73101655 0.40420004]
#  [0.53044271 0.43237879]
#  [0.62877932 0.41832014]
#  [0.60394895 0.37750714]
#  [0.2945717  0.41359277]
#  [0.66220052 0.37894702]
#  [0.75972018 0.57011875]
#  [0.33941101 0.53701446]
#  [0.40101886 0.62828852]
#  [0.50069713 0.61069438]
#  [0.77301476 0.55394713]
#  [0.30913125 0.49546648]
#  [0.27242627 0.26147181]
#  [0.52922501 0.42729262]
#  [0.50944238 0.75330298]
#  [0.51934974 0.5077821 ]
#  [0.60192435 0.37452048]
#  [0.73157847 0.45946645]
#  [0.40748818 0.55494898]
#  [0.46106079 0.65702428]
#  [0.67694322 0.00301857]
#  [0.3703744  0.62373022]
#  [0.79417595 0.64659796]
#  [0.71930223 0.37240564]]
# Training LogisticRegression :
# Best parameters selected: {'C': 1, 'max_iter': 100, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# Coefficient: [[ 4.52903625 -9.78304708]]
# Bias: [2.48821536]
# Training RandomForest :
# Best parameters selected: {'bootstrap': True, 'criterion': 'gini', 'max_depth': 30, 'max_features': None, 'min_samples_leaf': 4, 'n_estimators': 150}
# Feature importances: [0.42604964939315265, 0.5739503506068473]
# Training KNN :
# Best parameters selected: {'n_neighbors': 24, 'weights': 'uniform'}
# Distance metric: euclidean
# Training DecisionTree :
# Best parameters selected: {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'min_samples_leaf': 1, 'splitter': 'random'}
# Feature importances: [0.44003354552330093, 0.559966454476699]
# Training GradientBoosting :
# Best parameters selected: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'n_estimators': 20}
# Feature importances: [0.4343940340084152, 0.5656059659915847]
# Train score: [1.36640821 1.34812917 1.32979488 1.31115927 1.29360744 1.27577971
#  1.25870349 1.24238077 1.22599383 1.20950299 1.19382918 1.17847708
#  1.16326429 1.14782857 1.1333837  1.11871648 1.10398108 1.08972644
#  1.07567578 1.06218898]
# Training MLP :
# Best parameters selected: {'activation': 'relu', 'alpha': 0.0001, 'batch_size': 32, 'hidden_layer_sizes': (200, 100), 'learning_rate_init': 0.01, 'max_iter': 100}
# Best model type: MLP
# Performance of the best model type: 0.92

# %%
# Visualize the models' performance.
fig = plt.figure(figsize=(20, 8))
model_types, performance = zip(*models_performance)

plt.bar(model_types, performance, width=0.5)
plt.ylabel("Accuracy", size=20)
plt.ylim(0.8, 1)
plt.xlabel("Model type", size=20)
plt.xticks(size=15)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # 2. Example of make_circles.

# %%
# Generate dataset and preprocess.
X, y=make_circles(n_samples=500, shuffle=True, noise=0.1, random_state=123)

preprocessed_X = preprocess(X)
feature_matrix = pd.DataFrame(
    {"f0": preprocessed_X[:, 0], "f1": preprocessed_X[:, 1], "label": y}
)

# %%
# Visualize the dataset.
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
axs[0].scatter(X[:, 0], X[:, 1], c=y, s=15, cmap="viridis")
axs[0].set_title("Visualization of the raw dataset.", y=-0.1, fontsize=15)

axs[1].scatter(
    feature_matrix["f0"],
    feature_matrix["f1"],
    marker="o",
    s=15,
    c=feature_matrix["label"],
    cmap="viridis",
)
axs[1].set_title("Visualization of the preprocessed dataset.", y=-0.1, fontsize=15)
# Out:
# Text(0.5, -0.1, 'Visualization of the preprocessed dataset.')

# %%
# Split the dataset.
train_X, train_y, test_X, test_y = prepare_train_test_data(
    feature_matrix, ["f0", "f1"], test_ratio=0.2, random_state=123
)

# Train SVM with auto parameter optimization.
classifier, accuracy, feature_importance = train(
    train_X, train_y, test_X, test_y, model_type=ModelType.SVM, metrics=Metrics.Accuracy, display_cv_results=True
)
# Out:
# Best parameters selected: {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# Support vectors: [[0.68953936 0.14105671]
#  [0.77998317 0.33070839]
#  [0.41720885 0.84617717]
#  [0.2519901  0.71643139]
#  [0.17047435 0.25266911]
#  [0.08953496 0.59872997]
#  [0.71351246 0.20538575]
#  [0.56927017 0.1185826 ]
#  [0.79155314 0.25949085]
#  [0.77359029 0.28864784]
#  [0.7278821  0.22700235]
#  [0.10828976 0.66405821]
#  [0.76952046 0.20948103]
#  [0.78170866 0.20654432]
#  [0.75248008 0.79468161]
#  [0.20975202 0.22937807]
#  [0.11239754 0.55657497]
#  [0.16329667 0.64557695]
#  [0.31920441 0.84629372]
#  [0.24563019 0.79657221]
#  [0.76983266 0.75631   ]
#  [0.79564085 0.72342314]
#  [0.70246274 0.79242023]
#  [0.12479097 0.60829729]
#  [0.49241989 0.16050088]
#  [0.30491156 0.1194144 ]
#  [0.88073595 0.55065268]
#  [0.87785184 0.52303441]
#  [0.13472971 0.33165744]
#  [0.2076378  0.76951847]
#  [0.12944139 0.45854483]
#  [0.78681888 0.73630601]
#  [0.49085826 0.09944619]
#  [0.87515689 0.40227451]
#  [0.16088879 0.2470806 ]
#  [0.09864862 0.472296  ]
#  [0.25934908 0.75942031]
#  [0.26321727 0.14682809]
#  [0.12161576 0.31021638]
#  [0.81008697 0.33964093]
#  [0.41020789 0.18287573]
#  [0.12149395 0.63718382]
#  [0.17232545 0.34400445]
#  [0.44308789 0.8103584 ]
#  [0.51689468 0.12035946]
#  [0.12375884 0.64240334]
#  [0.30278758 0.80253354]
#  [0.56395657 0.14612622]
#  [0.33167494 0.18371409]
#  [0.22043931 0.71720295]
#  [0.5723895  0.83428753]
#  [0.74839341 0.7158639 ]
#  [0.84618752 0.73719599]
#  [0.64960641 0.82723439]
#  [0.38853212 0.10710971]
#  [0.69594523 0.17043476]
#  [0.25094302 0.23832984]
#  [0.60893478 0.1739003 ]
#  [0.59751362 0.16867377]
#  [0.86878446 0.38829678]
#  [0.34803268 0.1756481 ]
#  [0.22924454 0.74597313]
#  [0.36130802 0.12662584]
#  [0.19693644 0.27630508]
#  [0.79042111 0.28136762]
#  [0.12795696 0.54581734]
#  [0.84167561 0.43724471]
#  [0.82248828 0.58574874]
#  [0.08111412 0.55450713]
#  [0.86889482 0.53856541]
#  [0.55182415 0.81162633]
#  [0.18980847 0.21175746]
#  [0.20427882 0.70727661]
#  [0.31540281 0.79828291]
#  [0.18061577 0.30663823]
#  [0.67777589 0.19491294]
#  [0.09001694 0.70630073]]
# Cross-validated score of different parameter settings:     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.003837      0.000594         0.001015        0.000190       1
# 1        0.003429      0.000320         0.000870        0.000038      10
# 2        0.003323      0.000187         0.000807        0.000029     100
# 3        0.005861      0.000945         0.000792        0.000022    1000
# 4        0.004476      0.000037         0.001633        0.000017       1
# ..            ...           ...              ...             ...     ...
# 71       0.004760      0.000092         0.001257        0.000009    1000
# 72       0.002903      0.000014         0.000879        0.000010    1000
# 73       0.004553      0.000181         0.001627        0.000025    1000
# 74       0.004691      0.000031         0.001267        0.000014    1000
# 75       0.002889      0.000017         0.000886        0.000029    1000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale       linear
# 2        scale       linear
# 3        scale       linear
# 4         auto          rbf
# ..         ...          ...
# 71        0.01      sigmoid
# 72        0.01         poly
# 73       0.001          rbf
# 74       0.001      sigmoid
# 75       0.001         poly
#
#                                                params  split0_test_score  \
# 0      {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}             0.4000
# 1     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}             0.4625
# 2    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}             0.4625
# 3   {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}             0.4625
# 4          {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}             0.5750
# ..                                                ...                ...
# 71    {'C': 1000, 'gamma': 0.01, 'kernel': 'sigmoid'}             0.4625
# 72       {'C': 1000, 'gamma': 0.01, 'kernel': 'poly'}             0.5000
# 73       {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}             0.4625
# 74   {'C': 1000, 'gamma': 0.001, 'kernel': 'sigmoid'}             0.4000
# 75      {'C': 1000, 'gamma': 0.001, 'kernel': 'poly'}             0.5000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0              0.4000             0.5125             0.4125
# 1              0.4000             0.5125             0.4750
# 2              0.4000             0.5125             0.4750
# 3              0.4000             0.5125             0.4750
# 4              0.4375             0.5125             0.6125
# ..                ...                ...                ...
# 71             0.4000             0.5125             0.4750
# 72             0.5000             0.5125             0.5125
# 73             0.4000             0.5125             0.4750
# 74             0.4000             0.5125             0.4125
# 75             0.5000             0.5125             0.5125
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.5125           0.4475        0.053268               68
# 1              0.4000           0.4500        0.044017               64
# 2              0.4500           0.4600        0.036572               61
# 3              0.4500           0.4600        0.036572               61
# 4              0.5125           0.5300        0.060000               26
# ..                ...              ...             ...              ...
# 71             0.4000           0.4500        0.044017               64
# 72             0.5125           0.5075        0.006124               28
# 73             0.5125           0.4725        0.041382               58
# 74             0.5125           0.4475        0.053268               68
# 75             0.5125           0.5075        0.006124               28
#
# [76 rows x 16 columns]

# %%
# Display model's performance.
print('Accuracy on the test set:', accuracy)
print("Feature's importance:", feature_importance)

# Plot ROC curve.
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
plt.ylim(0, 1)
plot_performance(classifier, test_X.values, test_y, pos_label=0, ax=axs[0])
plot_performance(classifier, test_X.values, test_y, pos_label=1, ax=axs[0])

# Plot P-R curve
plot_performance(classifier, test_X.values, test_y, pos_label=0, ax=axs[1], roc=False)
plot_performance(classifier, test_X.values, test_y, pos_label=1, ax=axs[1], roc=False)
# Out:
# Accuracy on the test set: 0.81
# Feature's importance: [('f1', 0.22000000000000006), ('f0', 0.21400000000000005)]

# %%
# Visualize the prediction.
predict_y = classifier.predict(test_X)
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
axs[0].scatter(test_X.iloc[:, 0], test_X.iloc[:, 1], c=test_y, s=15, cmap="viridis")
axs[0].set_title("Visualization of the test set with true label.", y=-0.1, fontsize=15)

axs[1].scatter(
    test_X.iloc[:, 0], test_X.iloc[:, 1], marker="o", s=15, c=predict_y, cmap="viridis",
)
axs[1].set_title(
    "Visualization of the test set with model's prediction.", y=-0.1, fontsize=15
)
# Out:
# Text(0.5, -0.1, "Visualization of the test set with model's prediction.")

# %%
# Select the best model
models_performance = []
for model_type in ModelType:
    print("Training %s :" % model_type.value)
    classifier, accuracy, feature_importance = train(
        train_X,
        train_y,
        test_X,
        test_y,
        model_type=model_type,
        metrics=Metrics.Accuracy,
        n_jobs=20,
    )
    models_performance.append((model_type.value, accuracy))

models_performance.sort(key=lambda t: t[1], reverse=True)
print("Best model type:", models_performance[0][0])
print("Performance of the best model type:", models_performance[0][1])
# Out:
# Training SVM :
# Best parameters selected: {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# Support vectors: [[0.68953936 0.14105671]
#  [0.77998317 0.33070839]
#  [0.41720885 0.84617717]
#  [0.2519901  0.71643139]
#  [0.17047435 0.25266911]
#  [0.08953496 0.59872997]
#  [0.71351246 0.20538575]
#  [0.56927017 0.1185826 ]
#  [0.79155314 0.25949085]
#  [0.77359029 0.28864784]
#  [0.7278821  0.22700235]
#  [0.10828976 0.66405821]
#  [0.76952046 0.20948103]
#  [0.78170866 0.20654432]
#  [0.75248008 0.79468161]
#  [0.20975202 0.22937807]
#  [0.11239754 0.55657497]
#  [0.16329667 0.64557695]
#  [0.31920441 0.84629372]
#  [0.24563019 0.79657221]
#  [0.76983266 0.75631   ]
#  [0.79564085 0.72342314]
#  [0.70246274 0.79242023]
#  [0.12479097 0.60829729]
#  [0.49241989 0.16050088]
#  [0.30491156 0.1194144 ]
#  [0.88073595 0.55065268]
#  [0.87785184 0.52303441]
#  [0.13472971 0.33165744]
#  [0.2076378  0.76951847]
#  [0.12944139 0.45854483]
#  [0.78681888 0.73630601]
#  [0.49085826 0.09944619]
#  [0.87515689 0.40227451]
#  [0.16088879 0.2470806 ]
#  [0.75889206 0.25785013]
#  [0.20615991 0.20429703]
#  [0.83568616 0.50907332]
#  [0.28503353 0.77206835]
#  [0.06041522 0.49626204]
#  [0.88292369 0.57829509]
#  [0.41111894 0.12984939]
#  [0.12149395 0.63718382]
#  [0.17232545 0.34400445]
#  [0.44308789 0.8103584 ]
#  [0.51689468 0.12035946]
#  [0.12375884 0.64240334]
#  [0.30278758 0.80253354]
#  [0.56395657 0.14612622]
#  [0.33167494 0.18371409]
#  [0.22043931 0.71720295]
#  [0.5723895  0.83428753]
#  [0.74839341 0.7158639 ]
#  [0.84618752 0.73719599]
#  [0.64960641 0.82723439]
#  [0.38853212 0.10710971]
#  [0.69594523 0.17043476]
#  [0.25094302 0.23832984]
#  [0.60893478 0.1739003 ]
#  [0.59751362 0.16867377]
#  [0.86878446 0.38829678]
#  [0.34803268 0.1756481 ]
#  [0.22924454 0.74597313]
#  [0.36130802 0.12662584]
#  [0.19693644 0.27630508]
#  [0.79042111 0.28136762]
#  [0.12795696 0.54581734]
#  [0.84167561 0.43724471]
#  [0.82248828 0.58574874]
#  [0.08111412 0.55450713]
#  [0.86889482 0.53856541]
#  [0.55182415 0.81162633]
#  [0.18980847 0.21175746]
#  [0.20427882 0.70727661]
#  [0.31540281 0.79828291]
#  [0.18061577 0.30663823]
#  [0.67777589 0.19491294]
#  [0.09001694 0.70630073]]
# Training LogisticRegression :
# Best parameters selected: {'C': 0.01, 'max_iter': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# Coefficient: [[-0.00145786  0.00910523]]
# Bias: [-0.03371774]
# Training RandomForest :
# Best parameters selected: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 30, 'max_features': None, 'min_samples_leaf': 4, 'n_estimators': 10}
# Feature importances: [0.501447492532195, 0.4985525074678051]
# Training KNN :
# Best parameters selected: {'n_neighbors': 13, 'weights': 'uniform'}
# Distance metric: euclidean
# Training DecisionTree :
# Best parameters selected: {'criterion': 'entropy', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'splitter': 'best'}
# Feature importances: [0.5042185642271515, 0.4957814357728485]
# Training GradientBoosting :
# Best parameters selected: {'learning_rate': 0.2, 'loss': 'exponential', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 8, 'n_estimators': 20}
# Feature importances: [0.5057252082600666, 0.4942747917399335]
# Train score: [0.88114999 0.78172689 0.69856277 0.62458182 0.56082928 0.50722665
#  0.46310113 0.42235021 0.38711831 0.35681183 0.32660762 0.30122321
#  0.28172    0.26460374 0.24709401 0.23612602 0.22126917 0.20778727
#  0.19582817 0.18907133]
# Training MLP :
# Best parameters selected: {'activation': 'relu', 'alpha': 0.001, 'batch_size': 16, 'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001, 'max_iter': 200}
# Best model type: KNN
# Performance of the best model type: 0.82

# %%
# Visualize the models' performance.
fig = plt.figure(figsize=(20, 8))
model_types, performance = zip(*models_performance)

plt.bar(model_types, performance, width=0.5)
plt.ylabel("Accuracy", size=20)
plt.ylim(0, 1)
plt.xlabel("Model type", size=20)
plt.xticks(size=15)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
